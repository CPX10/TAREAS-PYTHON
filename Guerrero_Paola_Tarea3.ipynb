# %%
#valorActualBTC = 40349.40
valorActualBTC = 46000.85

# %% [markdown]
# # COTIZADOR BITCOIN VS DOLAR

# %%
from IPython.display import Image, display

# %%
display(Image(filename = "btc.png", width = 200))

# %%
btcCotizar = input("ingrese el valor en bitcoin")
# Out:
# ingrese el valor en bitcoin 3.78

# %%
valorEnDolares = float(btcCotizar) * valorActualBTC

# %% [markdown]
# # RESULTADO EN USD

# %%
display(Image(filename = "usd.png", width = 150))

# %%
#print(valorEnDolares )

print("El eqivalente de: "+ btcCotizar + "BTC en USD es: $" + str(valorEnDolares))
# Out:
# El eqivalente de: 3.78BTC en USD es: $173883.213
